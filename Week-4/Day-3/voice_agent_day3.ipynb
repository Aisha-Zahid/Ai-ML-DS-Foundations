# %% [markdown]
# # Week 4 Day 3 — UrduLish voice agent
#
# Memory demo + one pipeline turn.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('.').resolve()))
from src.pipeline import VoicePipeline
pipe = VoicePipeline()
for u in ['Budget 3 crore hai Karachi', 'DHA mein kya options hain?', 'Us se sasti koi option?']:
    r = pipe.turn(user_text=u, speak=False)
    print('U:', u)
    print('A:', r['reply'][:200], f"({r['total_ms']} ms)")
    print('mem:', r['memory'].get('budget_text'), r['memory'].get('area'))
    print('---')
